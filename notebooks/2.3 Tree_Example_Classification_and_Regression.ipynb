# %% [markdown]
# # Decision Trees ::
#
# **Class is implemented only using numpy and visualization are shown using matplotlib. Code for class of decision tree is given in trees.py file**

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Decision-Trees-::" data-toc-modified-id="Decision-Trees-::-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Decision Trees ::</a></span><ul class="toc-item"><li><span><a href="#Import-classifier-and-regressor-from-given-file-trees.py" data-toc-modified-id="Import-classifier-and-regressor-from-given-file-trees.py-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import classifier and regressor from given file <strong><em>trees.py</em></strong></a></span></li><li><span><a href="#For-dataset-and-spliting,-we-need-sklearn-(Optional,-if-you-have-your-own-data)" data-toc-modified-id="For-dataset-and-spliting,-we-need-sklearn-(Optional,-if-you-have-your-own-data)-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>For dataset and spliting, we need sklearn (Optional, if you have your own data)</a></span></li></ul></li><li><span><a href="#Classification-Tree" data-toc-modified-id="Classification-Tree-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Classification Tree</a></span><ul class="toc-item"><li><span><a href="#Iris-Dataset" data-toc-modified-id="Iris-Dataset-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Iris Dataset</a></span><ul class="toc-item"><li><span><a href="#Loading-and-spliting-for-training-and-testing" data-toc-modified-id="Loading-and-spliting-for-training-and-testing-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Loading and spliting for training and testing</a></span></li><li><span><a href="#Fitting-a-model-(displaying-the-tree-building)-with-different-modes" data-toc-modified-id="Fitting-a-model-(displaying-the-tree-building)-with-different-modes-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Fitting a model (displaying the tree building) with different modes</a></span><ul class="toc-item"><li><span><a href="#verbose=-1-(silence-mode)" data-toc-modified-id="verbose=-1-(silence-mode)-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>verbose=-1 (silence mode)</a></span></li><li><span><a href="#verbose=0-(silence-mode)" data-toc-modified-id="verbose=0-(silence-mode)-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>verbose=0 (silence mode)</a></span></li><li><span><a href="#verbose=1-(progress-bar)" data-toc-modified-id="verbose=1-(progress-bar)-2.1.2.3"><span class="toc-item-num">2.1.2.3&nbsp;&nbsp;</span>verbose=1 (progress bar)</a></span></li><li><span><a href="#verbose=2-(printing-tree-info)" data-toc-modified-id="verbose=2-(printing-tree-info)-2.1.2.4"><span class="toc-item-num">2.1.2.4&nbsp;&nbsp;</span>verbose=2 (printing tree info)</a></span></li><li><span><a href="#verbose=3-(printing-branches-only)" data-toc-modified-id="verbose=3-(printing-branches-only)-2.1.2.5"><span class="toc-item-num">2.1.2.5&nbsp;&nbsp;</span>verbose=3 (printing branches only)</a></span></li><li><span><a href="#verbose=4-(Plotting-tree..-while-building)" data-toc-modified-id="verbose=4-(Plotting-tree..-while-building)-2.1.2.6"><span class="toc-item-num">2.1.2.6&nbsp;&nbsp;</span>verbose=4 (Plotting tree.. while building)</a></span></li></ul></li><li><span><a href="#Plotting-the-resulting-tree" data-toc-modified-id="Plotting-the-resulting-tree-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Plotting the resulting tree</a></span></li><li><span><a href="#Plotting-Tree-with-same-color-branches" data-toc-modified-id="Plotting-Tree-with-same-color-branches-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Plotting Tree with same color branches</a></span></li><li><span><a href="#Predicting-and-computing-Accuracy" data-toc-modified-id="Predicting-and-computing-Accuracy-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Predicting and computing Accuracy</a></span></li></ul></li><li><span><a href="#Iris-data-with-smaller-tree" data-toc-modified-id="Iris-data-with-smaller-tree-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Iris data with smaller tree</a></span></li><li><span><a href="#Breast-Cancer-data" data-toc-modified-id="Breast-Cancer-data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Breast Cancer data</a></span><ul class="toc-item"><li><span><a href="#Fitting-model-with-displaying-the-details-of-tree-in-process-(verbose=4)" data-toc-modified-id="Fitting-model-with-displaying-the-details-of-tree-in-process-(verbose=4)-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Fitting model with displaying the details of tree in process (verbose=4)</a></span></li><li><span><a href="#Resulting-tree" data-toc-modified-id="Resulting-tree-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Resulting tree</a></span></li><li><span><a href="#Fitting-model-with-displaying-the-progress-only-(verbose=1)" data-toc-modified-id="Fitting-model-with-displaying-the-progress-only-(verbose=1)-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Fitting model with displaying the progress only (verbose=1)</a></span></li><li><span><a href="#Plotting-Decison-Tree" data-toc-modified-id="Plotting-Decison-Tree-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Plotting Decison Tree</a></span></li><li><span><a href="#Predicting-and-computing-MSE" data-toc-modified-id="Predicting-and-computing-MSE-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Predicting and computing MSE</a></span></li></ul></li></ul></li><li><span><a href="#Regression-Tree" data-toc-modified-id="Regression-Tree-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Regression Tree</a></span><ul class="toc-item"><li><span><a href="#Boston-House-price" data-toc-modified-id="Boston-House-price-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Boston House price</a></span></li><li><span><a href="#Boston-Data-with-smaller-tree" data-toc-modified-id="Boston-Data-with-smaller-tree-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Boston Data with smaller tree</a></span></li></ul></li></ul></div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import classifier and regressor from given file ***trees.py***

# %%
from spkit.ml import ClassificationTree, RegressionTree

# %% [markdown]
# ## For dataset and spliting, we need sklearn (Optional, if you have your own data)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Classification Tree

# %% [markdown]
# ## Iris Dataset

# %% [markdown]
# ### Loading and spliting for training and testing

# %%
data = datasets.load_iris()
X = data.data
y = data.target

feature_names = data.feature_names #Optional

Xt,Xs, yt, ys = train_test_split(X,y,test_size=0.3)

print(X.shape,y.shape, Xt.shape, yt.shape, Xs.shape, ys.shape)
# Out:
# (150, 4) (150,) (105, 4) (105,) (45, 4) (45,)

# %% [markdown]
# ### Fitting a model (displaying the tree building) with different modes

# %% [markdown]
# #### verbose=0 (silence mode)

# %%
clf = ClassificationTree()
clf.fit(Xt,yt,verbose=0,feature_names=feature_names)

# %% [markdown]
# #### verbose=1 (progress bar)

# %%
clf = ClassificationTree()
clf.fit(Xt,yt,verbose=1,feature_names=feature_names)
# Out:
# Number of features:: 4
# Number of samples :: 105
# ---------------------------------------
# |Building the tree.....................
# |subtrees::|100%|-------------------->||
# |.........................tree is buit!
# ---------------------------------------

# %% [markdown]
# #### verbose=2 (printing tree info)

# %%
clf = ClassificationTree()
clf.fit(Xt,yt,verbose=2,feature_names=feature_names)
# Out:
# Number of features:: 4
# Number of samples :: 105
# ---------------------------------------
# |Building the tree.....................
# |-Feature::3_petal length (cm) Gain::0.94 thr::3.0_Depth = 0
# |->True branch (>>>)..
# |--Feature::3_petal length (cm) Gain::0.72 thr::4.8_Depth = 1
# |-->True branch (>>>)..
# |---Feature::4_petal width (cm) Gain::0.16 thr::1.9_Depth = 2
# |--->False branch (<<<)..
# |---Feature::3_petal length (cm) Gain::0.19 thr::5.5_Depth = 3
# |--->False branch (<<<)..
# |---Feature::1_sepal length (cm) Gain::0.32 thr::6.7_Depth = 4
# |--->True branch (>>>)..
# |---->{Leaf Node:: value: 1 }_Depth =5
#
# |
# |--->False branch (<<<)..
# |---Feature::1_sepal length (cm) Gain::0.31 thr::6.1_Depth = 5
# |--->True branch (>>>)..
# |---->{Leaf Node:: value: 2 }_Depth =6
#
# |
# |--->False branch (<<<)..
# |---Feature::2_sepal width (cm) Gain::0.31 thr::3.0_Depth = 6
# |--->False branch (<<<)..
# |--->{Leaf Node:: value: 1 }_Depth =7
#
# |
# |--->True branch (>>>)..
# ...

# %% [markdown]
# #### verbose=3 (printing branches only)

# %%
clf = ClassificationTree()
clf.fit(Xt,yt,verbose=3,feature_names=feature_names)
# Out:
# Number of features:: 4
# Number of samples :: 105
# ---------------------------------------
# |Building the tree.....................
# None 0 |
# True 1 | T
# True 2 | TT
# True 3 | TTT
# False 3 | TTF
# True 4 | TTFT
# False 4 | TTFF
# True 5 | TTFFT
# False 5 | TTFFF
# True 6 | TTFFFT
# False 6 | TTFFFF
# True 7 | TTFFFFT
# True 8 | TTFFFFTT
# False 8 | TTFFFFTF
# False 7 | TTFFFFF
# False 2 | TF
# False 1 | F
# |
# |.........................tree is buit!
# ---------------------------------------

# %% [markdown]
# #### verbose=4 (Plotting tree.. while building)

# %%
# %matplotlib notebook

# %%
clf = ClassificationTree()
clf.fit(Xt,yt,verbose=4,feature_names=feature_names, randomBranch=True)
plt.close(clf.fig)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Number of features:: 4
# Number of samples :: 105
# ---------------------------------------
# |Building the tree.....................
# |
# |.........................tree is buit!
# ---------------------------------------

# %% [markdown]
# ### Plotting the resulting tree

# %%
plt.figure(figsize=(8,6))
clf.plotTree(show=True,DiffBranchColor=True,scale=False)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Plotting Tree with same color branches

# %%
plt.figure(figsize=(8,6))
clf.plotTree(show=True)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Predicting and computing Accuracy

# %%
ytp = clf.predict(Xt)
ysp = clf.predict(Xs)
print('Training Accuracy: ',np.mean(ytp==yt))
print('Testing  Accuracy: ',np.mean(ysp==ys))
# Out:
# Training Accuracy:  1.0
# Testing  Accuracy:  0.9333333333333333

# %% [markdown]
# ## Iris data with smaller tree

# %%
clf = ClassificationTree(max_depth=2)
clf.fit(Xt,yt,verbose=1,feature_names=feature_names)
#plt.figure(figsize=(15,8))
plt.figure(figsize=(5,5))
clf.plotTree(show=True,DiffBranchColor=True)
ytp = clf.predict(Xt)
ysp = clf.predict(Xs)
print('Training Accuracy: ',np.mean(ytp==yt))
print('Testing  Accuracy: ',np.mean(ysp==ys))
# Out:
# Number of features:: 4
# Number of samples :: 105
# ---------------------------------------
# |Building the tree.....................
# |subtrees::|100%|-------------------->||
# |.........................tree is buit!
# ---------------------------------------
# <img src="data:image/png;base64,..." width="500">
# Training Accuracy:  0.9619047619047619
# Testing  Accuracy:  0.9333333333333333

# %% [markdown]
# ## Breast Cancer data

# %%
data = datasets.load_breast_cancer()
X = data.data
y = data.target

feature_names = data.feature_names #Optional

Xt,Xs, yt, ys = train_test_split(X,y,test_size=0.3)

print(X.shape,y.shape, Xt.shape, yt.shape, Xs.shape, ys.shape)
# Out:
# (569, 30) (569,) (398, 30) (398,) (171, 30) (171,)

# %% [markdown]
# ### Fitting model with displaying the details of tree in process (verbose=4)

# %% [markdown]
# **While building tree, To first choose True branch and then False set randomBranch=False**

# %%
clf = ClassificationTree()
clf.fit(Xt,yt,verbose=4,feature_names=feature_names,randomBranch=False)
#plt.close(clf.fig)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Number of features:: 30
# Number of samples :: 398
# ---------------------------------------
# |Building the tree.....................
# |
# |.........................tree is buit!
# ---------------------------------------

# %% [markdown]
# **To randomly selevting True or False branch set randomBranch=True**

# %%
clf = ClassificationTree()
clf.fit(Xt,yt,verbose=4,feature_names=feature_names,randomBranch=True)
plt.close(clf.fig)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Number of features:: 30
# Number of samples :: 398
# ---------------------------------------
# |Building the tree.....................
# |
# |.........................tree is buit!
# ---------------------------------------

# %% [markdown]
# ### Resulting tree

# %%
plt.figure(figsize=(6,6))
clf.plotTree(show=True,DiffBranchColor=True,scale=False)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Fitting model with displaying the progress only (verbose=1)

# %%
clf = ClassificationTree()
clf.fit(Xt,yt,verbose=1,feature_names=feature_names)

plt.figure(figsize=(6,6))
clf.plotTree(show=True)
# Out:
# Number of features:: 30
# Number of samples :: 398
# ---------------------------------------
# |Building the tree.....................
# |subtrees::|100%|-------------------->|-
# |.........................tree is buit!
# ---------------------------------------
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Plotting Decison Tree

# %%
plt.figure(figsize=(6,6))
clf.plotTree(show=True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Predicting and computing MSE

# %%
ytp = clf.predict(Xt)
ysp = clf.predict(Xs)
print('Training Accuracy: ',np.mean(ytp==yt))
print('Testing  Accuracy: ',np.mean(ysp==ys))
# Out:
# Training Accuracy:  1.0
# Testing  Accuracy:  0.9532163742690059

# %% [markdown]
# **It's overfitting, try with smaller trees by decresing the max_depth of classifier**

# %% [markdown]
# # Regression Tree

# %% [markdown]
# ## Boston House price

# %%
data = datasets.load_boston()
X = data.data
y = data.target

feature_names = data.feature_names #Optional

Xt,Xs, yt, ys = train_test_split(X,y,test_size=0.3)

print(X.shape,y.shape, Xt.shape, yt.shape, Xs.shape, ys.shape)
# Out:
# (506, 13) (506,) (354, 13) (354,) (152, 13) (152,)

# %%
rgr = RegressionTree()
rgr.fit(Xt,yt,verbose=1,feature_names = feature_names)
# Out:
# Number of features:: 13
# Number of samples :: 354
# ---------------------------------------
# |Building the tree.....................
# |subtrees::|100%|-------------------->|\
# |.........................tree is buit!
# ---------------------------------------

# %%
# %matplotlib inline
plt.style.use('default')

# %%
plt.figure(figsize=(10,10))
rgr.plotTree(show=True,scale=False,DiffBranchColor=True)

# %%
plt.figure(figsize=(15,15))
rgr.plotTree(show=True,scale=True, showtitle =False, showDirection=False,DiffBranchColor=True)

# %%
# %matplotlib notebook
rgr = RegressionTree(max_depth=4)
rgr.fit(Xt,yt,verbose=4,feature_names = feature_names)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Number of features:: 13
# Number of samples :: 354
# ---------------------------------------
# |Building the tree.....................
# |
# |.........................tree is buit!
# ---------------------------------------

# %%
plt.figure(figsize=(10,6))
rgr.plotTree(show=True,scale=True, showtitle =False, showDirection=False,DiffBranchColor=True)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
ytp = rgr.predict(Xt)
ysp = rgr.predict(Xs)
print('Training MSE: ',np.mean((ytp-yt)**2))
print('Testing  MSE: ',np.mean((ysp-ys)**2))
# Out:
# Training MSE:  6.178914224439429
# Testing  MSE:  12.187349420981135

# %% [markdown]
# ## Boston Data with smaller tree

# %%
rgr = RegressionTree(max_depth=3)
rgr.fit(Xt,yt,verbose=1,feature_names = feature_names)
# Out:
# Number of features:: 13
# Number of samples :: 354
# ---------------------------------------
# |Building the tree.....................
# |subtrees::|100%|-------------------->|\
# |.........................tree is buit!
# ---------------------------------------

# %%
plt.figure(figsize=(8,6))
rgr.plotTree(show=True,scale=True, showtitle =True, showDirection=False,DiffBranchColor=True)

ytp = rgr.predict(Xt)
ysp = rgr.predict(Xs)
print('Training MSE: ',np.mean((ytp-yt)**2))
print('Testing  MSE: ',np.mean((ysp-ys)**2))
# Out:
# <img src="data:image/png;base64,..." width="800">
# Training MSE:  8.674185349676321
# Testing  MSE:  12.839154053729468
